# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuvankishore448/python-with-machine-learning/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], index=['one','two','three'], columns=['a','b','c'])
print(df)
# Out:
#        a  b  c
# one    1  2  3
# two    4  5  6
# three  7  8  9

# %%
#Taking the input from DataFrame and stroing in the Excel file
print("Taking the input from DataFrame and storing in the Excel file")
df.to_excel('d:\pandas_to_excel.xlsx',sheet_name='new_sheet_name')
# Out:
# Taking the input from DataFrame and storing in the Excel file
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipython-input-27056194.py:3: SyntaxWarning: invalid escape sequence '\p'
#   df.to_excel('d:\pandas_to_excel.xlsx',sheet_name='new_sheet_name')
