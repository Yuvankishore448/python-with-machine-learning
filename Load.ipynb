# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuvankishore448/python-with-machine-learning/blob/main/Load.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
d=pd.read_csv('employees details.csv')
print(d)
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0   677509        Drs.       Lois              H    Walker      F
# 1   940761         Ms.     Brenda              S  Robinson      F
# 2   428945         Dr.        Joe              W  Robinson      M
# 3   408351        Drs.      Diane              I     Evans      F
# 4   193819         Mr.   Benjamin              R   Russell      M
# ..     ...         ...        ...            ...       ...    ...
# 95  639892         Mr.       Jose              K      Hill      M
# 96  704709         Dr.     Harold              Z    Nelson      M
# 97  461593         Ms.     Nicole              O      Ward      F
# 98  392491        Mrs.    Theresa              R    Murphy      F
# 99  495141        Drs.      Tammy              B     Young      F
#
#                           E Mail     Father's Name       Mother's Name  \
# 0        lois.walker@hotmail.com     Donald Walker        Helen Walker
# ...

# %%
#Get the column heading
df=pd.DataFrame(d)
print(df.columns)
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Salary'],
#       dtype='object')

# %%
#Get the shape-(no.of rows,no.of columns)
print(df.shape)
# Out:
# (100, 11)

# %%
#Get the column
print("Salary",df['Salary'])
# Out:
# Salary 0     168251
# 1      51063
# 2      50155
# 3     180294
# 4     117642
#        ...
# 95    129774
# 96    156194
# 97     95673
# 98     51015
# 99     93650
# Name: Salary, Length: 100, dtype: int64

# %%
# Extract/slice the table values-
print(df[5:8])
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 5  499687         Mr.    Patrick              F    Bailey      M
# 6  539712         Ms.      Nancy              T     Baker      F
# 7  380086        Mrs.      Carol              V    Murphy      F
#
#                    E Mail  Father's Name     Mother's Name  \
# 5  patrick.bailey@aol.com   Ralph Bailey      Laura Bailey
# 6      nancy.baker@bp.com    Scott Baker        Judy Baker
# 7  carol.murphy@gmail.com  Eugene Murphy  Katherine Murphy
#
#   Mother's Maiden Name  Salary
# 5            Henderson   72305
# 6               Thomas   98189
# 7             Peterson   60918

# %%
#Get the particular row values
print("Particular person details",df.loc[10])
# Out:
# Particular person details Emp ID                                  231469
# Name Prefix                                Mr.
# First Name                               Ralph
# Middle Initial                               L
# Last Name                               Flores
# Gender                                       M
# E Mail                  ralph.flores@yahoo.com
# Father's Name                     Terry Flores
# Mother's Name                  Michelle Flores
# Mother's Maiden Name                     Moore
# Salary                                  118457
# Name: 10, dtype: object

# %%
#Get the particular row values through "Salary" identification
print(d.loc[d['Salary']==121587])
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 8  477616        Hon.    Frances              B     Young      F
#
#                     E Mail Father's Name  Mother's Name Mother's Maiden Name  \
# 8  frances.young@gmail.com    Fred Young  Lillian Young                 Diaz
#
#    Salary
# 8  121587

# %%
#Instead of company employ data set we can use student mark list dataset
df=d['Salary']/5
print("\nMake an average of total mark:\n",df)
# Out:
# Make an average of total mark:
#  0     33650.2
# 1     10212.6
# 2     10031.0
# 3     36058.8
# 4     23528.4
#        ...
# 95    25954.8
# 96    31238.8
# 97    19134.6
# 98    10203.0
# 99    18730.0
# Name: Salary, Length: 100, dtype: float64
